# %% [markdown]
# ## 1) Faça um programa que tenha a seguinte lista contendo os valores de gastos de uma empresa de papel [2172.54, 3701.35, 3518.09, 3456.61, 3249.38, 2840.82, 3891.45, 3075.26, 2317.64, 3219.08]. Com esses valores, faça um programa que calcule a média de gastos. Dica: use as funções built-in sum() e len().

# %%
#questao 1
papel = [2172.54, 3701.35, 3518.09, 3456.61, 3249.38, 2840.82, 3891.45, 3075.26, 2317.64, 3219.08]
tamanho = len(papel)
soma = sum(papel)
media = soma/tamanho
print(media)
# Out:
# 3144.222

# %% [markdown]
# ## 2) Com os mesmos dados da questão anterior, defina quantas compras foram realizadas acima de 3000 reais e calcule a porcentagem quanto ao total de compras.

# %%
# Filtra as compras acima de 3000
compras_acima_3000 = [valor for valor in papel if valor > 3000]

# Conta quantas são
quantidade = len(compras_acima_3000)

# Total de compras
total_compras = len(papel)

# Calcula a porcentagem
porcentagem = (quantidade / total_compras) * 100

# Exibe os resultados
print(f"Quantidade de compras acima de R$ 3000: {quantidade}")
print(f"Porcentagem: {porcentagem:.2f}%")
# Out:
# Quantidade de compras acima de R$ 3000: 7
# Porcentagem: 70.00%

# %% [markdown]
# ## 3) Faça um código que colete em uma lista 5 números inteiros quaisquer e imprima a lista. Exemplo: [1,4,7,2,4].

# %%
numeros = []  # Lista vazia para armazenar os números

# Coletando 5 números inteiros
for i in range(5):
    numero = int(input(f"Digite o {i+1}º número inteiro: "))
    numeros.append(numero)

# Imprimindo a lista
print("Lista de números:", numeros)
# Out:
# Digite o 1º número inteiro: 1
# Digite o 2º número inteiro: 2
# Digite o 3º número inteiro: 3
# Digite o 4º número inteiro: 4
# Digite o 5º número inteiro: 5
# Lista de números: [1, 2, 3, 4, 5]

# %% [markdown]
# ## 4) Colete novamente 5 inteiros e imprima a lista em ordem inversa à enviada.

# %%
# Coletar 5 números inteiros
numeros = []
for i in range(5):
    numero = int(input(f"Digite o {i+1}º número inteiro: "))
    numeros.append(numero)

# Imprimir a lista em ordem inversa
print("Lista em ordem inversa:")
print(numeros[::-1])
# Out:
# Digite o 1º número inteiro: 1
# Digite o 2º número inteiro: 2
# Digite o 3º número inteiro: 3
# Digite o 4º número inteiro: 4
# Digite o 5º número inteiro: 5
# Lista em ordem inversa:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ## 5) Faça um programa que, ao inserir um número qualquer, cria uma lista contendo todos os números primos entre 1 e o número digitado.

# %%
# Função para verificar se um número é primo
def eh_primo(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

# Entrada do usuário
limite = int(input("Digite um número: "))

# Criar lista com números primos entre 1 e o número digitado
primos = [i for i in range(1, limite + 1) if eh_primo(i)]

# Exibir a lista de primos
print("Números primos entre 1 e", limite, ":")
print(primos)
# Out:
# Digite um número: 11
# Números primos entre 1 e 11 :
# [2, 3, 5, 7, 11]

# %% [markdown]
# ## 6) Escreva um programa que peça uma data informando o dia, mês e ano e determine se ela é válida para uma análise.

# %%
from datetime import datetime

# Solicitar a data
dia = int(input("Digite o dia: "))
mes = int(input("Digite o mês: "))
ano = int(input("Digite o ano: "))

# Tentar criar uma data válida
try:
    data = datetime(ano, mes, dia)
    print("Data válida:", data.strftime("%d/%m/%Y"))
except ValueError:
    print("Data inválida.")
# Out:
# Digite o dia: 2
# Digite o mês: 3
# Digite o ano: 2000
# Data válida: 02/03/2000

# %% [markdown]
# ## 7) Para um estudo envolvendo o nível de multiplicação de bactérias em uma colônia, foi coletado o número de bactérias por dia (em milhares) e pode ser observado a seguir: [1.2, 2.1, 3.3, 5.0, 7.8, 11.3, 16.6, 25.1, 37.8, 56.9]. Tendo esses valores, faça um código que gere uma lista contendo o percentual de crescimento de bactérias por dia, comparando o número de bactérias em cada dia com o número de bactérias do dia anterior. Dica: para calcular o percentual de crescimento usamos a seguinte equação: 100 * (amostra_atual - amostra_passada) / (amostra_passada).

# %%
# Lista com o número de bactérias por dia (em milhares)
bacterias = [1.2, 2.1, 3.3, 5.0, 7.8, 11.3, 16.6, 25.1, 37.8, 56.9]

# Lista para armazenar os percentuais de crescimento
percentuais_crescimento = []

# Calcular o percentual de crescimento a partir do segundo dia
for i in range(1, len(bacterias)):
    crescimento = 100 * (bacterias[i] - bacterias[i - 1]) / bacterias[i - 1]
    percentuais_crescimento.append(crescimento)

# Exibir os resultados
for i, crescimento in enumerate(percentuais_crescimento, start=1):
    print(f"Crescimento do dia {i} para o dia {i+1}: {crescimento:.2f}%")
# Out:
# Crescimento do dia 1 para o dia 2: 75.00%
# Crescimento do dia 2 para o dia 3: 57.14%
# Crescimento do dia 3 para o dia 4: 51.52%
# Crescimento do dia 4 para o dia 5: 56.00%
# Crescimento do dia 5 para o dia 6: 44.87%
# Crescimento do dia 6 para o dia 7: 46.90%
# Crescimento do dia 7 para o dia 8: 51.20%
# Crescimento do dia 8 para o dia 9: 50.60%
# Crescimento do dia 9 para o dia 10: 50.53%

# %% [markdown]
# ## 8) Para uma seleção de produtos alimentícios, precisamos separar o conjunto de IDs dados por números inteiros sabendo que os produtos com ID par são doces e os com ID ímpar são amargos. Monte um código que colete 10 IDs. Depois, calcule e mostre a quantidade de produtos doces e amargos.

# %%
# Listas para armazenar os IDs doces e amargos
ids_doces = []
ids_amargos = []

# Coletar 10 IDs do usuário
print("Digite 10 IDs de produtos (números inteiros):")
for i in range(10):
    id_produto = int(input(f"ID {i+1}: "))
    if id_produto % 2 == 0:
        ids_doces.append(id_produto)
    else:
        ids_amargos.append(id_produto)

# Mostrar os resultados
print(f"\nQuantidade de produtos doces (IDs pares): {len(ids_doces)}")
print(f"Quantidade de produtos amargos (IDs ímpares): {len(ids_amargos)}")
# Out:
# Digite 10 IDs de produtos (números inteiros):
# ID 1: 10
# ID 2: 20
# ID 3: 33
# ID 4: 1
# ID 5: 1
# ID 6: 2
# ID 7: 3
# ID 8: 4
# ID 9: 5
# ID 10: 6
#
# Quantidade de produtos doces (IDs pares): 5
# Quantidade de produtos amargos (IDs ímpares): 5

# %% [markdown]
# ## 9) Desenvolva um programa que informa a nota de um(a) aluno(a) de acordo com suas respostas. Ele deve pedir a resposta desse(a) aluno(a) para cada questão e é preciso verificar se a resposta foi igual ao gabarito. Cada questão vale um ponto e existem as alternativas A, B, C ou D.
#
# Gabarito da prova:
# 01 - D
# 02 - A
# 03 - C
# 04 - B
# 05 - A
# 06 - D
# 07 - C
# 08 - C
# 09 - A
# 10 - B

# %%
gabarito = ['D', 'A', 'C', 'B', 'A', 'D', 'C', 'C', 'A', 'B']
acertos = 0

print("Digite as respostas do(a) aluno(a):")
for i in range(10):
    resposta = input(f"Questão {i+1} (A/B/C/D): ").strip().upper()
    if resposta == gabarito[i]:
        acertos += 1

print(f"\nNota final do(a) aluno(a): {acertos}/10")
# Out:
# Digite as respostas do(a) aluno(a):
# Questão 1 (A/B/C/D): A
# Questão 2 (A/B/C/D): B
# Questão 3 (A/B/C/D): D
# Questão 4 (A/B/C/D): E
# Questão 5 (A/B/C/D): F
# Questão 6 (A/B/C/D): A
# Questão 7 (A/B/C/D): a
# Questão 8 (A/B/C/D): a
# Questão 9 (A/B/C/D): a
# Questão 10 (A/B/C/D): a
#
# Nota final do(a) aluno(a): 1/10

# %% [markdown]
# ## 10) Um instituto de meteorologia deseja fazer um estudo de temperatura média de cada mês do ano. Para isso, você precisa fazer um código que colete e armazene essas temperaturas médias em uma lista. Depois, calcule a média anual das temperaturas e mostre todas as temperaturas acima da média anual e em que mês elas ocorreram, mostrando os meses por extenso (Janeiro, Fevereiro, etc.).

# %%
meses = ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho',
         'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro']

temperaturas = []

for mes in meses:
    temp = float(input(f"Informe a temperatura média de {mes}: "))
    temperaturas.append(temp)

media_anual = sum(temperaturas) / len(temperaturas)
print(f"\nTemperatura média anual: {media_anual:.2f}°C")
print("Meses com temperatura acima da média:")

for i, temp in enumerate(temperaturas):
    if temp > media_anual:
        print(f"{meses[i]} - {temp}°C")
# Out:
# Informe a temperatura média de Janeiro: 22
# Informe a temperatura média de Fevereiro: 22
# Informe a temperatura média de Março: 33
# Informe a temperatura média de Abril: 44
# Informe a temperatura média de Maio: 11
# Informe a temperatura média de Junho: 2
# Informe a temperatura média de Julho: 2
# Informe a temperatura média de Agosto: 3
# Informe a temperatura média de Setembro: 4
# Informe a temperatura média de Outubro: 5
# Informe a temperatura média de Novembro: 6
# Informe a temperatura média de Dezembro: 2
#
# Temperatura média anual: 13.00°C
# Meses com temperatura acima da média:
# Janeiro - 22.0°C
# Fevereiro - 22.0°C
# Março - 33.0°C
# Abril - 44.0°C

# %% [markdown]
# ## 11) Uma empresa de e-commerce está interessada em analisar as vendas dos seus produtos. Os dados das vendas foram armazenados em um dicionário:
#
# {'Produto A': 300, 'Produto B': 80, 'Produto C': 60,
#  'Produto D': 200, 'Produto E': 250, 'Produto F': 30}
# Copiar código
# Escreva um código que calcule o total de vendas e o produto mais vendido.

# %%
vendas = {
    'Produto A': 300, 'Produto B': 80, 'Produto C': 60,
    'Produto D': 200, 'Produto E': 250, 'Produto F': 30
}

total = sum(vendas.values())
produto_mais_vendido = max(vendas, key=vendas.get)

print(f"Total de vendas: {total}")
print(f"Produto mais vendido: {produto_mais_vendido} ({vendas[produto_mais_vendido]} vendas)")
# Out:
# Total de vendas: 920
# Produto mais vendido: Produto A (300 vendas)

# %% [markdown]
# ## 12) Uma pesquisa de mercado foi feita para decidir qual design de marca infantil mais agrada as crianças. A pesquisa foi feita e o votos computados podem ser observados abaixo:
#
# '''
# Tabela de votos da marca
# Design 1 - 1334 votos
# Design 2 - 982 votos
# Design 3 - 1751 votos
# Design 4 - 210 votos
# Design 5 - 1811 votos
# '''
#
# Adapte os dados fornecidos para uma estrutura de dicionário. A partir dele, informe o design vencedor e a porcentagem de votos recebidos.

# %%
votos = {
    'Design 1': 1334,
    'Design 2': 982,
    'Design 3': 1751,
    'Design 4': 210,
    'Design 5': 1811
}

total_votos = sum(votos.values())
vencedor = max(votos, key=votos.get)
percentual = (votos[vencedor] / total_votos) * 100

print(f"Design vencedor: {vencedor} com {percentual:.2f}% dos votos")
# Out:
# Design vencedor: Design 5 com 29.75% dos votos

# %% [markdown]
# ## 13) As pessoas colaboradoras de um setor da empresa que você trabalha vão receber um abono correspondente a 10% do salário devido ao ótimo desempenho do time. O setor financeiro solicitou sua ajuda para a verificação das consequências financeiras que esse abono irá gerar nos recursos. Assim, foi encaminhada para você uma lista com os salários que receberão o abono: [1172, 1644, 2617, 5130, 5532, 6341, 6650, 7238, 7685, 7782, 7903]. O abono de cada colaborador(a) não pode ser inferior a 200. Em código, transforme cada um dos salários em chaves de um dicionário e o abono de cada salário no elemento. Depois, informe o total de gastos com o abono, quantos(as) colaboradores(as) receberam o abono mínimo e qual o maior valor de abono fornecido.

# %%
salarios = [1172, 1644, 2617, 5130, 5532, 6341, 6650, 7238, 7685, 7782, 7903]
abonos = {}
total_abonos = 0
abono_minimo = 0
maior_abono = 0

for salario in salarios:
    abono = max(0.1 * salario, 200)
    abonos[salario] = abono
    total_abonos += abono
    if abono == 200:
        abono_minimo += 1
    if abono > maior_abono:
        maior_abono = abono

print(f"Total de gastos com abono: R${total_abonos:.2f}")
print(f"Colaboradores que receberam o abono mínimo: {abono_minimo}")
print(f"Maior valor de abono: R${maior_abono:.2f}")
# Out:
# Total de gastos com abono: R$6087.80
# Colaboradores que receberam o abono mínimo: 2
# Maior valor de abono: R$790.30

# %% [markdown]
# ## 14) Uma equipe de cientistas de dados está estudando a diversidade biológica em uma floresta. A equipe fez a coleta de informações sobre o número de espécies de plantas e animais em cada área dessa floresta e armazenou essas informações em um dicionário. Nele, a chave descreve a área dos dados e os valores nas listas correspondem às espécies de plantas e animais nas áreas, respectivamente.
#
# {'Área Norte': [2819, 7236],
#  'Área Leste': [1440, 9492],
#  'Área Sul': [5969, 7496],
#  'Área Oeste': [14446, 49688],
#  'Área Centro': [22558, 45148]}
# Copiar código
# Escreva um código para calcular a média de espécies por área e identificar a área com a maior diversidade biológica. Dica: use as funções built-in sum() e len().

# %%
floresta = {
    'Área Norte': [2819, 7236],
    'Área Leste': [1440, 9492],
    'Área Sul': [5969, 7496],
    'Área Oeste': [14446, 49688],
    'Área Centro': [22558, 45148]
}

maior_diversidade = ''
maior_total = 0

print("Média de espécies por área:")
for area, especies in floresta.items():
    media = sum(especies) / len(especies)
    print(f"{area}: {media:.2f}")
    if sum(especies) > maior_total:
        maior_total = sum(especies)
        maior_diversidade = area

print(f"\nÁrea com maior diversidade biológica: {maior_diversidade}")
# Out:
# Média de espécies por área:
# Área Norte: 5027.50
# Área Leste: 5466.00
# Área Sul: 6732.50
# Área Oeste: 32067.00
# Área Centro: 33853.00
#
# Área com maior diversidade biológica: Área Centro

# %% [markdown]
# ## 15) O setor de RH da sua empresa te pediu uma ajuda para analisar as idades de colaboradores(as) de 4 setores da empresa. Para isso, foram fornecidos os seguintes dados:
#
# {'Setor A': [22, 26, 30, 30, 35, 38, 40, 56, 57, 65],
#  'Setor B': [22, 24, 26, 33, 41, 49, 50, 54, 60, 64],
#  'Setor C': [23, 26, 26, 29, 34, 35, 36, 41, 52, 56],
#  'Setor D': [19, 20, 25, 27, 34, 39, 42, 44, 50, 65]}
#
# Sabendo que cada setor tem 10 colaboradores(as), construa um código que calcule a média de idade de cada setor, a idade média geral entre todos os setores e quantas pessoas estão acima da idade média geral.

# %%
setores = {
    'Setor A': [22, 26, 30, 30, 35, 38, 40, 56, 57, 65],
    'Setor B': [22, 24, 26, 33, 41, 49, 50, 54, 60, 64],
    'Setor C': [23, 26, 26, 29, 34, 35, 36, 41, 52, 56],
    'Setor D': [19, 20, 25, 27, 34, 39, 42, 44, 50, 65]
}

media_setores = {}
todas_idades = []

for setor, idades in setores.items():
    media = sum(idades) / len(idades)
    media_setores[setor] = media
    todas_idades.extend(idades)

media_geral = sum(todas_idades) / len(todas_idades)
acima_da_media = sum(1 for idade in todas_idades if idade > media_geral)

print("Média de idade por setor:")
for setor, media in media_setores.items():
    print(f"{setor}: {media:.2f} anos")

print(f"\nIdade média geral: {media_geral:.2f} anos")
print(f"Pessoas acima da média geral: {acima_da_media}")
# Out:
# Média de idade por setor:
# Setor A: 39.90 anos
# Setor B: 42.30 anos
# Setor C: 35.80 anos
# Setor D: 36.50 anos
#
# Idade média geral: 38.62 anos
# Pessoas acima da média geral: 18
